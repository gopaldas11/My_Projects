# %%
foren_api = "https://v6.exchangerate-api.com/v6/c55a8ad40b814b1e3f78de50/latest/USD"

# %%
import requests

# %%
response = requests.get(foren_api)

# %%
response.ok
# Out:
# True

# %%
response.status_code #200 means everything is in order
# Out:
# 200

# %%
response.text
# Out:
# '{\n "result":"success",\n "documentation":"https://www.exchangerate-api.com/docs",\n "terms_of_use":"https://www.exchangerate-api.com/terms",\n "time_last_update_unix":1769817601,\n "time_last_update_utc":"Sat, 31 Jan 2026 00:00:01 +0000",\n "time_next_update_unix":1769904001,\n "time_next_update_utc":"Sun, 01 Feb 2026 00:00:01 +0000",\n "base_code":"USD",\n "conversion_rates":{\n  "USD":1,\n  "AED":3.6725,\n  "AFN":65.5633,\n  "ALL":80.8050,\n  "AMD":378.7181,\n  "ANG":1.7900,\n  "AOA":920.4743,\n  "ARS":1452.2500,\n  "AUD":1.4325,\n  "AWG":1.7900,\n  "AZN":1.7000,\n  "BAM":1.6449,\n  "BBD":2.0000,\n  "BDT":122.2322,\n  "BGN":1.5956,\n  "BHD":0.3760,\n  "BIF":2969.0069,\n  "BMD":1.0000,\n  "BND":1.2689,\n  "BOB":6.9233,\n  "BRL":5.2036,\n  "BSD":1.0000,\n  "BTN":91.9140,\n  "BWP":13.5793,\n  "BYN":2.8345,\n  "BZD":2.0000,\n  "CAD":1.3574,\n  "CDF":2248.0082,\n  "CHF":0.7711,\n  "CLF":0.02177,\n  "CLP":860.3782,\n  "CNH":6.9548,\n  "CNY":6.9646,\n  "COP":3667.5765,\n  "CRC":495.3334
# ...

# %%
response.content
# Out:
# b'{\n "result":"success",\n "documentation":"https://www.exchangerate-api.com/docs",\n "terms_of_use":"https://www.exchangerate-api.com/terms",\n "time_last_update_unix":1769817601,\n "time_last_update_utc":"Sat, 31 Jan 2026 00:00:01 +0000",\n "time_next_update_unix":1769904001,\n "time_next_update_utc":"Sun, 01 Feb 2026 00:00:01 +0000",\n "base_code":"USD",\n "conversion_rates":{\n  "USD":1,\n  "AED":3.6725,\n  "AFN":65.5633,\n  "ALL":80.8050,\n  "AMD":378.7181,\n  "ANG":1.7900,\n  "AOA":920.4743,\n  "ARS":1452.2500,\n  "AUD":1.4325,\n  "AWG":1.7900,\n  "AZN":1.7000,\n  "BAM":1.6449,\n  "BBD":2.0000,\n  "BDT":122.2322,\n  "BGN":1.5956,\n  "BHD":0.3760,\n  "BIF":2969.0069,\n  "BMD":1.0000,\n  "BND":1.2689,\n  "BOB":6.9233,\n  "BRL":5.2036,\n  "BSD":1.0000,\n  "BTN":91.9140,\n  "BWP":13.5793,\n  "BYN":2.8345,\n  "BZD":2.0000,\n  "CAD":1.3574,\n  "CDF":2248.0082,\n  "CHF":0.7711,\n  "CLF":0.02177,\n  "CLP":860.3782,\n  "CNH":6.9548,\n  "CNY":6.9646,\n  "COP":3667.5765,\n  "CRC":495.333
# ...

# %%
response.json()
# Out:
# {'result': 'success',
#  'documentation': 'https://www.exchangerate-api.com/docs',
#  'terms_of_use': 'https://www.exchangerate-api.com/terms',
#  'time_last_update_unix': 1769817601,
#  'time_last_update_utc': 'Sat, 31 Jan 2026 00:00:01 +0000',
#  'time_next_update_unix': 1769904001,
#  'time_next_update_utc': 'Sun, 01 Feb 2026 00:00:01 +0000',
#  'base_code': 'USD',
#  'conversion_rates': {'USD': 1,
#   'AED': 3.6725,
#   'AFN': 65.5633,
#   'ALL': 80.805,
#   'AMD': 378.7181,
#   'ANG': 1.79,
#   'AOA': 920.4743,
#   'ARS': 1452.25,
#   'AUD': 1.4325,
#   'AWG': 1.79,
#   'AZN': 1.7,
#   'BAM': 1.6449,
#   'BBD': 2.0,
#   'BDT': 122.2322,
#   'BGN': 1.5956,
#   'BHD': 0.376,
#   'BIF': 2969.0069,
#   'BMD': 1.0,
#   'BND': 1.2689,
#   'BOB': 6.9233,
#   'BRL': 5.2036,
#   'BSD': 1.0,
#   'BTN': 91.914,
#   'BWP': 13.5793,
#   'BYN': 2.8345,
#   'BZD': 2.0,
#   'CAD': 1.3574,
#   'CDF': 2248.0082,
#   'CHF': 0.7711,
#   'CLF': 0.02177,
#   'CLP': 860.3782,
#   'CNH': 6.9548,
# ...

# %%
import json

# %%
print(json.dumps(response.json(), indent=4))
# Out:
# {
#     "result": "success",
#     "documentation": "https://www.exchangerate-api.com/docs",
#     "terms_of_use": "https://www.exchangerate-api.com/terms",
#     "time_last_update_unix": 1769817601,
#     "time_last_update_utc": "Sat, 31 Jan 2026 00:00:01 +0000",
#     "time_next_update_unix": 1769904001,
#     "time_next_update_utc": "Sun, 01 Feb 2026 00:00:01 +0000",
#     "base_code": "USD",
#     "conversion_rates": {
#         "USD": 1,
#         "AED": 3.6725,
#         "AFN": 65.5633,
#         "ALL": 80.805,
#         "AMD": 378.7181,
#         "ANG": 1.79,
#         "AOA": 920.4743,
#         "ARS": 1452.25,
#         "AUD": 1.4325,
#         "AWG": 1.79,
#         "AZN": 1.7,
#         "BAM": 1.6449,
#         "BBD": 2.0,
#         "BDT": 122.2322,
#         "BGN": 1.5956,
#         "BHD": 0.376,
#         "BIF": 2969.0069,
#         "BMD": 1.0,
#         "BND": 1.2689,
#         "BOB": 6.9233,
#         "BRL": 5.2036,
#         "BSD": 1.0,
#         "BTN": 91.914,
# ...

# %%
prem_url = foren_api + "?symbols=USD,GBP"
prem_url
# Out:
# 'https://v6.exchangerate-api.com/v6/c55a8ad40b814b1e3f78de50/latest/USD?symbols=USD,GBP'

# %%
response = requests.get(prem_url)
response
# Out:
# <Response [200]>

# %%
data = response.json()
data
# Out:
# {'result': 'success',
#  'documentation': 'https://www.exchangerate-api.com/docs',
#  'terms_of_use': 'https://www.exchangerate-api.com/terms',
#  'time_last_update_unix': 1769817601,
#  'time_last_update_utc': 'Sat, 31 Jan 2026 00:00:01 +0000',
#  'time_next_update_unix': 1769904001,
#  'time_next_update_utc': 'Sun, 01 Feb 2026 00:00:01 +0000',
#  'base_code': 'USD',
#  'conversion_rates': {'USD': 1,
#   'AED': 3.6725,
#   'AFN': 65.5633,
#   'ALL': 80.805,
#   'AMD': 378.7181,
#   'ANG': 1.79,
#   'AOA': 920.4743,
#   'ARS': 1452.25,
#   'AUD': 1.4325,
#   'AWG': 1.79,
#   'AZN': 1.7,
#   'BAM': 1.6449,
#   'BBD': 2.0,
#   'BDT': 122.2322,
#   'BGN': 1.5956,
#   'BHD': 0.376,
#   'BIF': 2969.0069,
#   'BMD': 1.0,
#   'BND': 1.2689,
#   'BOB': 6.9233,
#   'BRL': 5.2036,
#   'BSD': 1.0,
#   'BTN': 91.914,
#   'BWP': 13.5793,
#   'BYN': 2.8345,
#   'BZD': 2.0,
#   'CAD': 1.3574,
#   'CDF': 2248.0082,
#   'CHF': 0.7711,
#   'CLF': 0.02177,
#   'CLP': 860.3782,
#   'CNH': 6.9548,
# ...
