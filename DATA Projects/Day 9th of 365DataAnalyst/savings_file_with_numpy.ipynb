# %%
import numpy as np

# %%
data = np.genfromtxt("Lending-Company-Saving.csv",
                     delimiter=",",
                     dtype=np.str_)

# %%
data
# Out:
# array([['LoanID', 'StringID', 'Product', ..., 'Location', 'Region',
#         'TotalPrice'],
#        ['1', 'id_1', 'Product B', ..., 'Location 2', 'Region 2',
#         '16600.0'],
#        ['2', 'id_2', 'Product B', ..., 'Location 3', '', '16600.0'],
#        ...,
#        ['1041', 'id_1041', 'Product B', ..., 'Location 23', 'Region 4',
#         '16600.0'],
#        ['1042', 'id_1042', 'Product C', ..., 'Location 52', 'Region 6',
#         '15600.0'],
#        ['1043', 'id_1043', 'Product B', ..., 'Location 142', 'Region 6',
#         '16600.0']], shape=(1044, 7), dtype='<U14')

# %%
print(data)
# Out:
# [['LoanID' 'StringID' 'Product' ... 'Location' 'Region' 'TotalPrice']
#  ['1' 'id_1' 'Product B' ... 'Location 2' 'Region 2' '16600.0']
#  ['2' 'id_2' 'Product B' ... 'Location 3' '' '16600.0']
#  ...
#  ['1041' 'id_1041' 'Product B' ... 'Location 23' 'Region 4' '16600.0']
#  ['1042' 'id_1042' 'Product C' ... 'Location 52' 'Region 6' '15600.0']
#  ['1043' 'id_1043' 'Product B' ... 'Location 142' 'Region 6' '16600.0']]

# %%
np.save("Numpy_file_saving", data)

# %%
lendin_data_load = np.load("Numpy_file_saving.npy")

# %%
print(lendin_data_load)
# Out:
# [['LoanID' 'StringID' 'Product' ... 'Location' 'Region' 'TotalPrice']
#  ['1' 'id_1' 'Product B' ... 'Location 2' 'Region 2' '16600.0']
#  ['2' 'id_2' 'Product B' ... 'Location 3' '' '16600.0']
#  ...
#  ['1041' 'id_1041' 'Product B' ... 'Location 23' 'Region 4' '16600.0']
#  ['1042' 'id_1042' 'Product C' ... 'Location 52' 'Region 6' '15600.0']
#  ['1043' 'id_1043' 'Product B' ... 'Location 142' 'Region 6' '16600.0']]

# %%
np.array_equal(data, lendin_data_load)
# Out:
# True

# %%
np.savez("leading_company_Archive", company = data, data_saved = lendin_data_load)

# %%
loading_archive = np.load("leading_company_Archive.npz")

# %%
loading_archive.files
# Out:
# ['company', 'data_saved']

# %%
print(loading_archive["data_saved"])
# Out:
# [['LoanID' 'StringID' 'Product' ... 'Location' 'Region' 'TotalPrice']
#  ['1' 'id_1' 'Product B' ... 'Location 2' 'Region 2' '16600.0']
#  ['2' 'id_2' 'Product B' ... 'Location 3' '' '16600.0']
#  ...
#  ['1041' 'id_1041' 'Product B' ... 'Location 23' 'Region 4' '16600.0']
#  ['1042' 'id_1042' 'Product C' ... 'Location 52' 'Region 6' '15600.0']
#  ['1043' 'id_1043' 'Product B' ... 'Location 142' 'Region 6' '16600.0']]

# %%
print(loading_archive["company"])
# Out:
# [['LoanID' 'StringID' 'Product' ... 'Location' 'Region' 'TotalPrice']
#  ['1' 'id_1' 'Product B' ... 'Location 2' 'Region 2' '16600.0']
#  ['2' 'id_2' 'Product B' ... 'Location 3' '' '16600.0']
#  ...
#  ['1041' 'id_1041' 'Product B' ... 'Location 23' 'Region 4' '16600.0']
#  ['1042' 'id_1042' 'Product C' ... 'Location 52' 'Region 6' '15600.0']
#  ['1043' 'id_1043' 'Product B' ... 'Location 142' 'Region 6' '16600.0']]

# %%
new_data = np.genfromtxt("Lending-Company-Saving.csv",
                           delimiter=",",
                           dtype=np.str_)

# %%
np.savetxt("Numpy_saving_txt.txt", new_data, fmt="%s", delimiter=",")

# %%
lending_data_testing = np.genfromtxt("Numpy_saving_txt.txt", delimiter=",", dtype=np.str_)
print(lending_data_testing)
# Out:
# [['LoanID' 'StringID' 'Product' ... 'Location' 'Region' 'TotalPrice']
#  ['1' 'id_1' 'Product B' ... 'Location 2' 'Region 2' '16600.0']
#  ['2' 'id_2' 'Product B' ... 'Location 3' '' '16600.0']
#  ...
#  ['1041' 'id_1041' 'Product B' ... 'Location 23' 'Region 4' '16600.0']
#  ['1042' 'id_1042' 'Product C' ... 'Location 52' 'Region 6' '15600.0']
#  ['1043' 'id_1043' 'Product B' ... 'Location 142' 'Region 6' '16600.0']]

# %%
loading_data_save = np.load
