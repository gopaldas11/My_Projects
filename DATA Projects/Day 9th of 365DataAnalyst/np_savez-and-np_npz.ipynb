# %%
import numpy as np

# %%
data = np.genfromtxt("Lending-Company-Saving.csv",
                     delimiter=",",
                     dtype=np.str_)
lendin_data_load = np.load("Numpy_file_saving.npy")

# %%
np.savez("Savez_Numpy_file_saving", data, lendin_data_load)

# %%
np_savez_load = np.load("Savez_Numpy_file_saving.npz") #We have to all which data from Archive we are calling by= ["arr_0"] - this formet. got it !?

# %%
print(np_savez_load["arr_0"])
# Out:
# [['LoanID' 'StringID' 'Product' ... 'Location' 'Region' 'TotalPrice']
#  ['1' 'id_1' 'Product B' ... 'Location 2' 'Region 2' '16600.0']
#  ['2' 'id_2' 'Product B' ... 'Location 3' '' '16600.0']
#  ...
#  ['1041' 'id_1041' 'Product B' ... 'Location 23' 'Region 4' '16600.0']
#  ['1042' 'id_1042' 'Product C' ... 'Location 52' 'Region 6' '15600.0']
#  ['1043' 'id_1043' 'Product B' ... 'Location 142' 'Region 6' '16600.0']]

# %%
print(np_savez_load["arr_1"])
# Out:
# [['LoanID' 'StringID' 'Product' ... 'Location' 'Region' 'TotalPrice']
#  ['1' 'id_1' 'Product B' ... 'Location 2' 'Region 2' '16600.0']
#  ['2' 'id_2' 'Product B' ... 'Location 3' '' '16600.0']
#  ...
#  ['1041' 'id_1041' 'Product B' ... 'Location 23' 'Region 4' '16600.0']
#  ['1042' 'id_1042' 'Product C' ... 'Location 52' 'Region 6' '15600.0']
#  ['1043' 'id_1043' 'Product B' ... 'Location 142' 'Region 6' '16600.0']]

# %%
np_savez_load = np.load("Savez_Numpy_file_saving.npz")
