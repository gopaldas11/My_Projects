# %% [markdown]
# **Pandas series - .values, .array , .to_numpy()**

# %%
import pandas as pd
import numpy as np

# %%
price_category = pd.Series({"Product A": 223322, "Product B": 223323, "Product C": 223323})
price_category
# Out:
# Product A    223322
# Product B    223323
# Product C    223323
# dtype: int64

# %%
price_category.values
# Out:
# array([223322, 223323, 223323])

# %%
type(price_category.values)
# Out:
# numpy.ndarray

# %%
price_category.array
# Out:
# <NumpyExtensionArray>
# [223322, 223323, 223323]
# Length: 3, dtype: int64

# %%
price_category.to_numpy()
# Out:
# array([223322, 223323, 223323])
